# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('1.csv')

# %%
data.head(5)
# Out:
#          id  product_variant_id  selling_price   rrp_price base_price  \
# 0  18752043             1977385       850000.0    850000.0         \N
# 1  18752022             1977380     12550000.0  12550000.0         \N
# 2  18752046             1977380     12500000.0  12500000.0         \N
# 3  18751982             1977374       310000.0    310000.0         \N
# 4  18752018             1977374       300000.0    300000.0         \N
#
#   buy_price  order_limit start_at end_at tags  show_in_price_history  active  \
# 0        \N            1       \N     \N   \N                      1       1
# 1        \N            2       \N     \N   \N                      1       0
# 2        \N            2       \N     \N   \N                      1       1
# 3        \N            2       \N     \N   \N                      1       0
# 4        \N            2       \N     \N   \N                      1       1
#
#          created_at  product_id  marketplace_seller_id
# ...

# %%
data.isnull().sum()
# Out:
# id                       0
# product_variant_id       0
# selling_price            0
# rrp_price                0
# base_price               0
# buy_price                0
# order_limit              0
# start_at                 0
# end_at                   0
# tags                     0
# show_in_price_history    0
# active                   0
# created_at               0
# product_id               0
# marketplace_seller_id    0
# dtype: int64

# %%
data.tags.unique()
# Out:
# array(['\\N', 'selling_and_sales', 'incredible_offer'], dtype=object)

# %%
data.loc[data['buy_price'] != '\\N']
# Out:
#                id  product_variant_id  selling_price   rrp_price base_price  \
# 3221     18610202             1964164      2350000.0   2450000.0    2350000
# 3284     18596702             1963651      2690000.0   2690000.0    2690000
# 7209     18647551             1954799     36990000.0  39990000.0   36990000
# 7220     18647550             1954759     36990000.0  37990000.0   36990000
# 7275     18647547             1954685     27990000.0  30000000.0   27990000
# ...           ...                 ...            ...         ...        ...
# 1047200  12451999             1447555      8770000.0   8770000.0    8770000
# 1047201  13688837             1447555      8460000.0   8770000.0    8770000
# 1047202  11501838             1447555      8140000.0   8770000.0    8220000
# 1047203  11900772             1447555      8460000.0   8770000.0    8470000
# 1047204  12002982             1447555      8470000.0   8770000.0    8470000
#
# ...

# %%
data.loc[data['end_at'] != '\\N']
# Out:
#                id  product_variant_id  selling_price  rrp_price base_price  \
# 763      18723299             1973584      1690000.0  1950000.0          0
# 809      18723298             1973450      6250000.0  6500000.0          0
# 1881     18731279             1969409       490000.0   520000.0          0
# 2237     18689235             1968436       590000.0   710000.0          0
# 2313     18685904             1968256       826500.0   870000.0          0
# ...           ...                 ...            ...        ...        ...
# 1047542  17866120             1447150       172800.0   216000.0          0
# 1047543  14978263             1447150       108000.0   216000.0          0
# 1047589  13668806             1447098       349000.0   450000.0          0
# 1047676  12549137             1446996      4620000.0  5400000.0          0
# 1047917  16171842             1446823       100000.0   140000.0          0
#
# ...

# %%
data.loc[data['created_at'] != '\\N']
# Out:
#                id  product_variant_id  selling_price   rrp_price base_price  \
# 0        18752043             1977385       850000.0    850000.0         \N
# 1        18752022             1977380     12550000.0  12550000.0         \N
# 2        18752046             1977380     12500000.0  12500000.0         \N
# 3        18751982             1977374       310000.0    310000.0         \N
# 4        18752018             1977374       300000.0    300000.0         \N
# ...           ...                 ...            ...         ...        ...
# 1048570  17551915             1446820      3923000.0   3923000.0         \N
# 1048571  17553313             1446820      3900000.0   3900000.0         \N
# 1048572  17553335             1446820      3899000.0   3899000.0         \N
# 1048573  17553355             1446820      3898000.0   3898000.0         \N
# 1048574  17553384             1446820      3897000.0   3897000.0         \N
#
# ...
